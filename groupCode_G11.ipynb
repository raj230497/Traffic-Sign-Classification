# %% [markdown]
# # <font color=white> CMT307 Applied Machine Learning </font>
# <a class="anchor" id="main_title"></a>
# ## Coursework 2 : 2021-2022 Spring Semester
# ### Group 11
#
#
# | Name      | Surname            | Student ID | e-mail                                                                      |
# |-----------|--------------------|------------|-----------------------------------------------------------------------------|
# | Raj Mahendra      | Gohil     | 21098035        | [gohilr@cardiff.ac.uk](mailto:gohilr@cardiff.ac.uk)                         |
# | Marissa   | Folami             | 1888429          | [folamim@cardiff.ac.uk](mailto:folamim@cardiff.ac.uk)                       |
# | Aishwarya | Mangesh Narvekar   |  2068104          | [narvekara@cardiff.ac.uk](mailto:narvekara@cardiff.ac.uk)                   |
# | Yanyan    | Jin                | 21072217   | [jiny26@cardiff.ac.uk](mailto:jiny26@cardiff.ac.uk)                         |
# | Jing      | Guo                | 1647806    | [guoj36@cardiff.ac.uk](mailto:guoj36@cardiff.ac.uk)                         |
# | Simran    | Mandal             |    2023961        | [mandalsa@cardiff.ac.uk](mailto:mandalsa@cardiff.ac.uk)                     |
# | Ashwanth  | Nadarajan          | 21124676        | [nadarajana@cardiff.ac.uk](mailto:nadarajana@cardiff.ac.uk)                 |
# | Harshith  | Pathapati Gajendra |       21099949     | [pathapatigajendrah@cardiff.ac.uk](mailto:pathapatigajendrah@cardiff.ac.uk) |

# %% [markdown]
# ### **This ipynb notebook contains all the tasks performed by teams T1, T2 and T3**

# %% [markdown]
# # 1. Few things to know before running the script

# %% [markdown]
# ## 1.1 The folders and files in our project

# %% [markdown]
# The **data** can be retrieve at:
# https://sid.erda.dk/public/archives/daaeac0d7ce1152aea9b61d9f1e19370/published-archive.html. And in our project the official training data (GTSRB_Final_Test_Images.zip) and the official test dataset (GTSRB_Final_Training_Images.zip) were used
#
# The contents of our project are as follows:
# <br/>

# %%
print("""
project                                //root path
├─.ipynb_checkpoints  
├─data                              //Train and test dataset.
│  ├─Tmp_Data                     //tmp data.                                          
│  ├─GTSRB_Final_Test_Images  
│  │  └─GTSRB  
│  │      └─Final_Test  
│  │          └─Images            //The ppm picture of test set.
│  └─GTSRB_Final_Training_Images  
│      └─GTSRB  
│          └─Final_Training  
│              └─Images  
│                  ├─00000        //The ppm picture of train set of first category.
│                  ├─00001        //...
│                  ├─00002
│                  ├─00003
│                  ├─00004
│                  ├─00005
│                  ├─00006
│                  ├─00007
│                  ├─00008
│                  ├─00009
│                  ├─00010
│                  ├─00011
│                  ├─00012
│                  ├─00013
│                  ├─00014
│                  ├─00015
│                  ├─00016
│                  ├─00017
│                  ├─00018
│                  ├─00019
│                  ├─00020
│                  ├─00021
│                  ├─00022
│                  ├─00023
│                  ├─00024
│                  ├─00025
│                  ├─00026
│                  ├─00027
│                  ├─00028
│                  ├─00029
│                  ├─00030
│                  ├─00031
│                  ├─00032
│                  ├─00033
│                  ├─00034
│                  ├─00035
│                  ├─00036
│                  ├─00037
│                  ├─00038
│                  ├─00039
│                  ├─00040
│                  ├─00041
│                  └─00042
└─pictureOutput //The picture we draw
""")
# Out:
# project                                //root path
# ├─.ipynb_checkpoints
# ├─data                              //Train and test dataset.
# │  ├─Tmp_Data                     //tmp data.
# │  ├─GTSRB_Final_Test_Images
# │  │  └─GTSRB
# │  │      └─Final_Test
# │  │          └─Images            //The ppm picture of test set.
# │  └─GTSRB_Final_Training_Images
# │      └─GTSRB
# │          └─Final_Training
# │              └─Images
# │                  ├─00000        //The ppm picture of train set of first category.
# │                  ├─00001        //...
# │                  ├─00002
# │                  ├─00003
# │                  ├─00004
# │                  ├─00005
# │                  ├─00006
# │                  ├─00007
# │                  ├─00008
# │                  ├─00009
# │                  ├─00010
# │                  ├─00011
# │                  ├─00012
# │                  ├─00013
# │                  ├─00014
# │                  ├─00015
# │                  ├─00016
# │                  ├─00017
# │                  ├─00018
# │                  ├─00019
# │                  ├─00020
# │                  ├─00021
# │                  ├─00022
# │                  ├─00023
# │                  ├─00024
# │                  ├─00025
# │                  ├─00026
# │                  ├─00027
# │                  ├─00028
# │                  ├─00029
# │                  ├─00030
# │                  ├─00031
# │                  ├─00032
# │                  ├─00033
# │                  ├─00034
# │                  ├─00035
# │                  ├─00036
# │                  ├─00037
# │                  ├─00038
# │                  ├─00039
# │                  ├─00040
# │                  ├─00041
# │                  └─00042
# └─pictureOutput //The picture we draw

# %% [markdown]
# ##1.2 The modules we need

# %%
# Import required modules
import numpy as np
import os
import sys
import random
from datetime import datetime
import pickle
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from skimage.transform import resize
import matplotlib
matplotlib.use('Agg')                                                           #For frontend
import matplotlib.pyplot as plt
from matplotlib.image import imread
import seaborn as sns
# %matplotlib inline
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
import tqdm                                                                     #Progress bar
import warnings
import cv2
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical                               #For One Hot Encoding

# %% [markdown]
# ## 1.3 Common Function and variable definition

# %%
def load_npy(directory, name="data"):
    '''
    Function
    ----------
    Load data saved as npy format.
    
    Parameters
    ----------
    directory : String
    The npy file address.
    name:String
    the name of the npy file.
    
    Return
    ----------
    numpy array from npy file.

    '''
    name = str(name)
    try:
        print( name + ' loading···')
        data = np.load(directory, allow_pickle=True)
        print( name + ' loading succeeded')
        return data

    except:
        print(name + 'not exist!')
        return None

    
    
def ppm2numpy(directory):
    '''
    Function
    ----------
    Convert the ppm pictures in the directory into a numpy array,and return an array with the whole list of pictures.
    
    Parameters
    ----------
    directory : String
    
    Return
    ----------
    numpy array whose items are decoded ppm pictures

    '''
    files_all = os.listdir(directory)
    files = []
    for file in files_all:
        if ".ppm" in file:
            files.append(plt.imread(os.path.join(directory,file))) 
    return np.array(files, dtype=object)


def plot_picture(picture,text):
    """
    Function
    ----------
    Draw a picture, given an array object.
    
    Parameters
    ----------
    picture: np.array
    the array object of a picture
    text:String
    the title of the picture
    
    Return
    ----------
    None
    
    """
    plt.figure()
    plt.imshow(picture, cmap = 'gray')
    plt.title(text)
    plt.show()

# %% [markdown]
# Variable definition（Localhost Root directory and change for your own link if use this way）

# %%
train_data_dir = "/Users/c21098035/OneDrive - Cardiff University/Desktop/project307-g11/data/GTSRB_Final_Training/GTSRB/Final_Training/Images/"
test_data_dir = "/Users/c21098035/OneDrive - Cardiff University/Desktop/project307-g11/data/GTSRB_Final_Test_Images/GTSRB/Final_Test/Images/"
Tmp_Data_dir = "/Users/c21098035/OneDrive - Cardiff University/Desktop/project307-g11/data/Tmp_Data/"
pictureOutput = "/Users/c21098035/OneDrive - Cardiff University/Desktop/project307-g11/pictureOutput/"

# %% [markdown]
# If you using Google colab with Google cloud drive please load thses module before run the rest of sequence

# %%
from google.colab import drive 
drive.mount('/content/drive',force_remount=True)

train_data_dir = "/content/drive/MyDrive/ML_CW2/GTSRB_Final_Training_Images/GTSRB/Final_Training/Images/"
test_data_dir = "/content/drive/MyDrive/ML_CW2/GTSRB_Final_Test_Images/GTSRB/Final_Test/Images/"
Tmp_Data_dir = "/content/drive/MyDrive/ML_CW2/Tmp_Data/"
pictureOutput = "/content/drive/MyDrive/ML_CW2/pictureOutput/"
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1.4 Basic information of data set

# %% [markdown]
# ### 1.4.1 Category label

# %% [markdown]
# The German Traffic Sign Recognition Benchmark (GTSRB) contains 43 types of traffic signs. Each sign corresponds to a unique index and is called a category. And the following cell shows the comparison between category and index. For example, category index 0 corresponds to the traffic sign "Max Speed 20 km/h", category index 1 corresponds to the traffic sign "Max Speed 30 km/h", etc.

# %%
#Traffic signs
#The index of sign corresponds to the name of the folder where the picture is located

category_names = [
    "Max Speed 20 km/h",
    "Max Speed 30 km/h",
    "Max Speed 50 km/h",
    "Max Speed 60 km/h",
    "Max Speed 70 km/h",
    "Max Speed 80 km/h",
    "End of 80 km/h zone",
    "Max Speed 100 km/h",
    "Max Speed 120 km/h",
    "No passing",
    "No passing for vehicles over 3.5 tonnes",
    "Priority",
    "Priority road",
    "Yield",
    "Stop",
    "Road closed",
    "Vehicles over 3.5 tonnes prohibited",
    "Do not enter",
    "General danger",
    "Left curve",
    "Right curve",
    "Double curve",
    "Uneven road surface",
    "Slippery when wet or dirty",
    "Road narrows",
    "Roadworks",
    "Traffic signals ahead",
    "Pedestrians",
    "Watch for children",
    "Bicycle crossing",
    "Ice - snow",
    "Wild animal crossing",
    "End of all restrictions",
    "Turn right ahead",
    "Turn left ahead",
    "Ahead only",
    "Ahead or turn right only",
    "Ahead or turn left only",
    "Pass by on right",
    "Pass by on left",
    "Roundabout",
    "End of no passing zone",
    "End of no passing zone for trucks"
    ]
for i,item in enumerate(category_names):
  print("{1}---{0}".format(item,i))
# Out:
# 0---Max Speed 20 km/h
# 1---Max Speed 30 km/h
# 2---Max Speed 50 km/h
# 3---Max Speed 60 km/h
# 4---Max Speed 70 km/h
# 5---Max Speed 80 km/h
# 6---End of 80 km/h zone
# 7---Max Speed 100 km/h
# 8---Max Speed 120 km/h
# 9---No passing
# 10---No passing for vehicles over 3.5 tonnes
# 11---Priority
# 12---Priority road
# 13---Yield
# 14---Stop
# 15---Road closed
# 16---Vehicles over 3.5 tonnes prohibited
# 17---Do not enter
# 18---General danger
# 19---Left curve
# 20---Right curve
# 21---Double curve
# 22---Uneven road surface
# 23---Slippery when wet or dirty
# 24---Road narrows
# 25---Roadworks
# 26---Traffic signals ahead
# 27---Pedestrians
# 28---Watch for children
# 29---Bicycle crossing
# 30---Ice - snow
# 31---Wild animal crossing
# 32---End of all restrictions
# 33---Turn right ahead
# 34---Turn left ahead
# 35---Ahead only
# 36---Ahead or turn right only
# 37---Ahead or turn left only
# 38---Pass by on right
# 39---Pass by on left
# 40---Roundabout
# 41---End of no passing zone
# 42---End of no passing zone for trucks

# %%
num_of_categories=len(category_names)                                           #Total number of categories
print(num_of_categories)
# Out:
# 43

# %% [markdown]
# ### 1.4.2 Training set

# %% [markdown]
# Build training dataset and get the length, width, category and information of pictures in training set. Because convert the picture to numpy will take a long time, so the converted data will be saved and can be called directly when it is used next time.

# %%
#Check whether the length, width and category data of the training set exist. If so, read it directly. Otherwise, generate and save it

if "x_train.npy" in os.listdir(Tmp_Data_dir) and "y_train.npy" in os.listdir(Tmp_Data_dir):
    x_train = load_npy(os.path.join(Tmp_Data_dir,"x_train.npy"), name="x_train.npy")
    y_train = load_npy(os.path.join(Tmp_Data_dir,"y_train.npy"), name="y_train.npy")
else:
    y_train = []
    x_train = []
    for folder in os.listdir(train_data_dir):
        images = ppm2numpy(os.path.join(train_data_dir,folder))
        x_train.append(images)
        y_train.extend([int(folder)]*len(images))
    x_train = np.concatenate(x_train, axis=0, out=None, dtype=None, casting="same_kind")
    np.save(os.path.join(Tmp_Data_dir,"x_train.npy") , x_train)
    np.save(os.path.join(Tmp_Data_dir,"y_train.npy"), y_train)
    
if "train_info.csv" not in os.listdir(Tmp_Data_dir) :
    train_info = {}
    widths = []
    heights = []
    for picture in x_train:
        widths.append(picture.shape[0])
        heights.append(picture.shape[1])
    train_info["Width"] = widths
    train_info["Height"] = heights
    train_info["IndexId"] = y_train

    train_info_df = pd.DataFrame(train_info)
    train_info_df.to_csv(os.path.join(Tmp_Data_dir, "train_info.csv"), index = False)
    print(train_info_df.head(5))
# Out:
# x_train.npy loading···
# x_train.npy loading succeeded
# y_train.npy loading···
# y_train.npy loading succeeded

# %% [markdown]
# ### 1.4.3 Testing set

# %% [markdown]
# Build training dataset and read the length, width, category and information of pictures in test set.

# %%
#Check whether the length, width and category data of the test set exist.If so, read it directly. Otherwise, generate and save it

if "x_test.npy" in os.listdir(Tmp_Data_dir) and "y_test.npy" in os.listdir(Tmp_Data_dir):
    x_test = load_npy(os.path.join(Tmp_Data_dir,"x_test.npy"), name="x_test.npy")
    y_test = load_npy(os.path.join(Tmp_Data_dir,"y_test.npy"), name="y_test.npy")
else:
    x_test = ppm2numpy(test_data_dir)
    y_test =  np.array(pd.read_csv("/content/drive/MyDrive/ML_CW2/GT-final_test.csv",sep=";")["ClassId"])
    np.save(os.path.join(Tmp_Data_dir,"x_test.npy") , x_test)
    np.save(os.path.join(Tmp_Data_dir,"y_test.npy"), y_test)
# Out:
# x_test.npy loading···
# x_test.npy loading succeeded
# y_test.npy loading···
# y_test.npy loading succeeded

# %% [markdown]
# ### 1.4.4 show some picture in test set, given an array object:

# %%
for i in range(5):
    plot_picture(x_test[i],category_names)

# %% [markdown]
# # 2. Descriptive Analysis

# %% [markdown]
# The scope of this section is to get a general idea of the whole dataset.
#
# 1,We will load the the info data and show some examples of train and test data.
#
# 2.We will start creating a graph to see the length and width distribution of the pictures.
#
# 3.We will start creating a barplot to explore average length and width of pictures for each category
#
# 4.We will start creating a histogram to see how many pictures are available for each category.

# %% [markdown]
# ## 2.1 Info data load

# %%
train_df = pd.read_csv(os.path.join(Tmp_Data_dir, "train_info.csv"))
print(train_df.head())
test_df = pd.read_csv("/content/drive/MyDrive/ML_CW2/GT-final_test.csv",sep=";")
print(test_df.head())
# Out:
#    Width  Height  IndexId
# 0     61      64       40
# 1     51      52       40
# 2     40      40       40
# 3     45      46       40
# 4     71      71       40
#     Filename  Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId
# 0  00000.ppm     53      54       6       5      48      49       16
# 1  00001.ppm     42      45       5       5      36      40        1
# 2  00002.ppm     48      52       6       6      43      47       38
# 3  00003.ppm     27      29       5       5      22      24       33
# 4  00004.ppm     60      57       5       5      55      52       11

# %% [markdown]
# ## 2.2 Data Visualizsation

# %% [markdown]
# ### 2.2.1 Observe pictures randomly in the training set and test set

# %% [markdown]
#  Inspect random pictures from the train directory for each category

# %%
plt.figure(figsize=(15,50))
category_nums = os.listdir(train_data_dir)
picture_loc = 1
for i,c in enumerate(category_nums):
    category = category_names[int(c)]
    imgs = [img for img in os.listdir(os.path.join(train_data_dir,c)) if ".ppm" in img]
    for j in range(1,4):
        plt.subplot(len(category_nums),3,picture_loc)
        picture_loc += 1
        img = random.choice(imgs)
        random_img_path = train_data_dir + c + "/" + img
        rand_img = imread(random_img_path)
        plt.imshow(rand_img)
        plt.xlabel(rand_img.shape[1], fontsize = 10)
        #width of image
        plt.ylabel(rand_img.shape[0], fontsize = 10)
        #height of image
        plt.title(category)
        
plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
                wspace=0.6, hspace=1)
plt.savefig(os.path.join(pictureOutput,"Inspect random pictures from the train directory for each category.png"))

# %% [markdown]
# Inspect 10 random pictures from the test directory

# %%
imgs = [item for item in os.listdir(test_data_dir) if ".ppm" in item]
plt.figure(figsize=(20,5))
for i in range(1,11):
    plt.subplot(2,5,i)
    img = random.choice(imgs)
    rand_img = imread(os.path.join(test_data_dir,img))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    #width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)
    #height of image
    plt.title(category_names[test_df.ClassId.values[int(img.replace(".ppm",""))]])

plt.subplots_adjust(left=None, bottom=None, right=None, top=None,
                wspace=0.6, hspace=0.5)
plt.savefig(os.path.join(pictureOutput,"Inspect 10 random pictures from the test directory.png"))

# %% [markdown]
# ### 2.2.2 The width and height distribution of pictures

# %% [markdown]
# Create two lines to explore the width and Height distribution of all pictures

# %%
fig = plt.figure(figsize=(10, 10))
for i,item in enumerate(["Width","Height"]):
    tmp = fig.add_subplot(1, 2 , i+1)
    fig.set_figheight(5)
    fig.set_figwidth(10)
    width_distribution = train_df.groupby([item]).count()
    tmp.plot(width_distribution.index, width_distribution["IndexId"], color = 'green')
    tmp.set_title(item, fontsize=20)
fig.tight_layout(pad=8.0)
fig.suptitle("The width & Height distribution of pictures", fontsize=20, y= 1.0)
plt.savefig(os.path.join(pictureOutput,"The width and height distribution of pictures.png"))
plt.show()

# %% [markdown]
# Create some lines to explore the width distribution of pictures per category:

# %%
df_width = train_df[["Width","IndexId"]]
df_width["Category"] = [category_names[item] for item in y_train]
fig = plt.figure(figsize=(25,25))

# Create a collection of axes names for the following subplot:
axes = [category for category in category_names]
for i in range(len(category_names)) :
    axes[i] = fig.add_subplot(9, 5 , i+1)
    fig.set_figheight(40)
    fig.set_figwidth(40)
    category = category_names[i]
    values = df_width[df_width.Category == category]
    tmp_data = values.groupby("Width").count()
    axes[i].plot(tmp_data.index, tmp_data["IndexId"], color = 'green')  
    axes[i].set_title(category_names[i])

fig.tight_layout(pad=8.0)
fig.suptitle("The width distribution of pictures per category", fontsize=40, y= 1.0)
plt.savefig(os.path.join(pictureOutput,"The width distribution of pictures per category.png"))
plt.show()

# %% [markdown]
# We can see that the length or width of the pictures is not exactly same, so we need to resize all the picture to the same size during the data processing.

# %% [markdown]
# ### 2.2.3 Number of pictures per category

# %% [markdown]
# At the this step we will create a barplot to explore number of pictures per category.

# %%
#Count the number of pictures of each type

train_counts = train_df.IndexId.value_counts()
test_counts = test_df.ClassId.value_counts()
print("Train set:\n",train_counts.head())
print("Test set:\n",train_counts.head())

#Draw the number of pictures per category.
fig = plt.figure(figsize=(30, 25))
num_df = train_df.groupby("IndexId").count()
fig.set_figheight(15)
fig.set_figwidth(20)

#Train set
tmp = fig.add_subplot(1, 2 ,1)
tmp.barh(range(len(train_counts)), train_counts.values, color = 'm')
labels = [ category_names[i] for i in train_counts.index ]
tmp.set_yticks(range(len(train_counts)))
tmp.set_yticklabels(labels)
tmp.set_title("Number of pictures in train data")

#Test set
tmp = fig.add_subplot(1, 2 ,2)
tmp.barh(range(len(test_counts)), test_counts.values, color = 'c')
labels = [ category_names[i] for i in test_counts.index ]
tmp.set_yticks(range(len(test_counts)))
tmp.set_yticklabels(labels)
tmp.set_title("Number of pictures in test data")

fig.tight_layout(pad=8.0)
fig.suptitle("Number of pictures per category", fontsize=20, y= 1.0)
plt.savefig(os.path.join(pictureOutput,"Number of pictures per category.png"))
plt.show()
# Out:
# Train set:
#  2     2250
# 1     2220
# 13    2160
# 12    2100
# 38    2070
# Name: IndexId, dtype: int64
# Test set:
#  2     2250
# 1     2220
# 13    2160
# 12    2100
# 38    2070
# Name: IndexId, dtype: int64

# %% [markdown]
# ### 2.2.4 Distribution of pixel intensity per category

# %% [markdown]
# Distribution of picture's average intensity per category

# %%
#Draw the picture's average intensity per category

picture_means = [ picture.mean() for picture in x_train]
picture_df = pd.DataFrame( list(zip(picture_means, [category_names[item] for item in y_train])), columns=['Picture_means', 'Category']  )
fig = plt.figure(figsize=(25,25))
axes = [category  for category in category_names]
for i in range(len(category_names)) :  
    axes[i] = fig.add_subplot(9, 5 , i+1)    
    fig.set_figheight(40)
    fig.set_figwidth(40)
    category = category_names[i]
    values = picture_df[picture_df.Category == category]["Picture_means"]
    axes[i].hist([values], bins = 10, facecolor = 'g')
    axes[i].axis('equal')  
    axes[i].set_title(category_names[i])
fig.tight_layout(pad=8.0)
fig.suptitle("Distribution of pixel intensity per category", fontsize=40, y= 1.0)
plt.savefig(os.path.join(pictureOutput,"pixel intensity distribution.png"))
plt.show()

# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# ## 3.1 Loading the training data

# %% [markdown]
# Resizing and converting the images to get rid of the faulty images for efficient training

# %%
#Pre-processing the Training data

train_data_dir="/content/drive/MyDrive/ML_CW2/GTSRB_Final_Training_Images/GTSRB/Final_Training/Images/" #redefining the data directory

category_nums=['00000','00001','00002','00003','00004','00005','00006','00007','00008','00009','00010','00011',
               '00012','00013','00014','00015','00016','00017','00018','00019','00020','00021','00022','00023','00024','00025','00026',
               '00027','00028','00029','00030','00031','00032','00033','00034','00035','00036','00037','00038','00039','00040','00041','00042']

#Must reference the folders by name

#Set desired height and width, inferred from the data exploration results
IMAGE_HEIGHT=35; IMAGE_WIDTH=35 

#Create an empty list for the preprocessed data
preprocessed_data=[]
broken_images=[]

for i in category_nums:                                                                 #Iterate over each folder name to get the images from each folder
    path=os.path.join(train_data_dir,i)                                                 #Path to each data folder (joins the quoted number and the general directory path)
    category_index=category_nums.index(i)                                               #Take the index values as arbitrary classification values
    for img in os.listdir(path):
      try:
        img_array=cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)              #Convert to array, rgb data ~3x size of greyscale therefore convert to greyscale for less space used
        resized_image_array=cv2.resize(img_array,(IMAGE_HEIGHT,IMAGE_WIDTH))            #Take each image and resize to the same dimensions
        equalisation_image=cv2.equalizeHist(resized_image_array)                        #Histogram equalisation tachnique to fix contrast issues in the images - equalise all images to a standard contrast.
        #Alternate normalisation clause
        normalised_image_array=tf.keras.utils.normalize(equalisation_image,axis=1)      #Normalise the numbers between 0 and 1
        preprocessed_data.append([normalised_image_array, category_index])              #Add the fully processed data to the list
        
      except Exception as e:
        broken_images.append([img_array, category_index])                               #Pass over broken images

print("Length of preprocessed data of the training set is:", len(preprocessed_data))
print("Length of number of broken images is:", len(broken_images))

#Shuffle the data in order to stop neural network continuously predicting the same category one after the other
from random import shuffle
shuffle(preprocessed_data)
print(preprocessed_data)
# Out:
# Length of preprocessed data of the training set is: 39209
# Length of number of broken images is: 43
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# Dividing processed images into input variables and output variables

# %%
x_train=[]                                                                       #Define empty lists
y_train=[]
for array, category in preprocessed_data:
  x_train.append(array)
  y_train.append(category)

plt.imshow(x_train[0],cmap='gray')                                              #This is the image
print(y_train[0])                                                               #This is the category the image falls under
# Out:
# 13

# %%
x_train=np.array(x_train).reshape(-1,IMAGE_HEIGHT,IMAGE_WIDTH,1)                #Have to add '1' term for the dimension of greyscale
print("Shape of x_train is:", x_train.shape)
y_train=np.array(y_train)
print("Shape of x_train is:", y_train.shape)
# Out:
# Shape of x_train is: (39209, 35, 35, 1)
# Shape of x_train is: (39209,)

# %% [markdown]
# ## 3.2 Loading the test data

# %%
#Loading the test.csv file into a dataframe to get the category labels
y_test_df = pd.read_csv('/content/drive/MyDrive/ML_CW2/GT-final_test.csv', sep = ';')

# %% [markdown]
# Performing the same loading and preprocessing technique to get the test data and later splitting the data into input and output variables

# %%
#Pre-processing the Test data

test_data_dir="/content/drive/MyDrive/ML_CW2/GTSRB_Final_Test_Images/GTSRB/Final_Test/Images/"        #Redefining the data directory


#Set desired height and width, inferred from the data exploration results
IMAGE_HEIGHT=35; IMAGE_WIDTH=35 

#Create an empty list for the preprocessed data
preprocessed_data_test=[]
broken_images_test=[]


for img in os.listdir(test_data_dir):
    try:
        
        img_array=cv2.imread(os.path.join(test_data_dir,img), cv2.IMREAD_GRAYSCALE)           #Convert to array, rgb data ~3x size of greyscale therefore convert to greyscale for less space used
        resized_image_array=cv2.resize(img_array,(IMAGE_HEIGHT,IMAGE_WIDTH))                  #Take each image and resize to the same dimensions
        equalisation_image=cv2.equalizeHist(resized_image_array)                              #Histogram equalisation tachnique to fix contrast issues in the images, i.e. equalise all images to a standard contrast.
        
        #Alternate normalisation clause
        normalised_image_array=tf.keras.utils.normalize(equalisation_image,axis=1)            #Normalise the numbers between 0 and 1
        
        category_index_test = y_test_df.loc[y_test_df.Filename == img, 'ClassId'].item()      #Getting Category label from the csv file

        preprocessed_data_test.append([normalised_image_array, category_index_test])          #Add the fully processed data to the list
        #plt.imshow(normalised_image_array, cmap='gray')
        #plt.show()
        
    except:
        print('Broken image = {}'.format(img))

print("Length of preprocessed data of the test set is:", len(preprocessed_data_test))

shuffle(preprocessed_data_test)                                                               #Data shuffling

x_test=[]                                                                                     #Define empty lists
y_test=[]

# Splitting test data into input and output variables
for array, category in preprocessed_data_test:
  x_test.append(array)
  y_test.append(category)

x_test=np.array(x_test).reshape(-1,IMAGE_HEIGHT,IMAGE_WIDTH,1)                                #Have to add '1' term for the dimension of greyscale
y_test=np.array(y_test)
# Out:
# Broken image = GT-final_test.csv
# Broken image = GT-final_test.gsheet
# Broken image = 00095 (1).ppm
# Broken image = 00092 (1).ppm
# Broken image = 00088 (1).ppm
# Broken image = 00090 (1).ppm
# Broken image = 00089 (1).ppm
# Broken image = 00093 (1).ppm
# Broken image = 00091 (1).ppm
# Length of preprocessed data of the test set is: 12630

# %%
y_test
# Out:
# array([ 4, 38, 24, ...,  1, 16, 18])

# %%
y_train
# Out:
# array([13,  7, 38, ..., 12, 25,  4])

# %% [markdown]
# Getting the shape of x_train, x_test, y_train, y_test

# %%
print("x_train.shape", x_train.shape)
print("x_test.shape", x_test.shape)
print("y_train.shape", y_train.shape)
print("y_test.shape", y_test.shape)
# Out:
# x_train.shape (39209, 35, 35, 1)
# x_test.shape (12630, 35, 35, 1)
# y_train.shape (39209,)
# y_test.shape (12630,)

# %% [markdown]
# Converting class vector to binary classes. This is a part of processing the data before feeding it to the model.

# %%
#One Hot Encoding

y_train = to_categorical(y_train, num_of_categories)
y_test = to_categorical(y_test, num_of_categories)

print(y_train.shape)
print(y_test.shape)
# Out:
# (39209, 43)
# (12630, 43)

# %% [markdown]
# # 4. Model implementation

# %% [markdown]
# ## 4.1 Initializing the model

# %% [markdown]
# Incrementally build the model

# %%
#Building the model

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu', input_shape=x_train.shape[1:]))
model.add(Conv2D(filters=32, kernel_size=(5,5), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.25))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(rate=0.5))
model.add(Dense(43, activation='softmax'))

warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
#Compiling the model

model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=['accuracy'])

# %%
#Summmary of the model

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 31, 31, 32)        832
#
#  conv2d_1 (Conv2D)           (None, 27, 27, 32)        25632
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 32)       0
#  )
#
#  dropout (Dropout)           (None, 13, 13, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 11, 11, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 9, 9, 64)          36928
#
#  max_pooling2d_1 (MaxPooling  (None, 4, 4, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 4, 4, 64)          0
#
#  flatten (Flatten)           (None, 1024)              0
#
#  dense (Dense)               (None, 256)               262400
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 43)                11051
#
# =================================================================
# Total params: 355,339
# Trainable params: 355,339
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 4.2 Training the model

# %%
#Final training of the model

history = model.fit(x_train, y_train, batch_size=35, epochs=5, validation_data=(x_test, y_test))
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# Epoch 1/5
# 1121/1121 [==============================] - 232s 206ms/step - loss: 1.1487 - accuracy: 0.6706 - val_loss: 0.3484 - val_accuracy: 0.9042
# Epoch 2/5
# 1121/1121 [==============================] - 231s 206ms/step - loss: 0.2836 - accuracy: 0.9099 - val_loss: 0.2552 - val_accuracy: 0.9310
# Epoch 3/5
# 1121/1121 [==============================] - 234s 209ms/step - loss: 0.1904 - accuracy: 0.9397 - val_loss: 0.2067 - val_accuracy: 0.9438
# Epoch 4/5
# 1121/1121 [==============================] - 231s 206ms/step - loss: 0.1454 - accuracy: 0.9548 - val_loss: 0.1713 - val_accuracy: 0.9553
# Epoch 5/5
# 1121/1121 [==============================] - 231s 206ms/step - loss: 0.1200 - accuracy: 0.9619 - val_loss: 0.1865 - val_accuracy: 0.9552

# %%
model.save("Traffic_signs_model.h5")  #Saving the model

# %% [markdown]
# ## 4.3 Plotting graphs

# %% [markdown]
# Visuliazing for accuracy and loss

# %%
#Plotting a graph for Accuracy vs Epochs

plt.figure(0)
plt.plot(history.history['accuracy'], label='training accuracy')
plt.plot(history.history['val_accuracy'], label='val accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Plotting a graph for Loss vs Epochs

plt.figure(1)
plt.plot(history.history['loss'], label='training loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#Plotting a graph for Training accuracy and Validation accuaracy vs Epochs

pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %% [markdown]
# ## 4.4 Evaluation of model

# %%
# Evaluating the model

model.evaluate(x_test, y_test)
# Out:
# 395/395 [==============================] - 15s 39ms/step - loss: 0.1865 - accuracy: 0.9552
# [0.18647803366184235, 0.9551860690116882]

# %% [markdown]
# ## 4.5 Predictions on test data

# %%
#Making predictions on the test data

from PIL import Image 

y_test_pred = pd.read_csv('/content/drive/MyDrive/ML_CW2/GT-final_test.csv', sep = ';') #Getting Category labels and images from the csv file

labels = y_test_pred["ClassId"].values
imgs = y_test_pred["Filename"].values

data=[]
counter = 0                                                                     #Counter to helpkeep track of the loop
IMG_SIZE = 35

for img in imgs:                                                                #Loading and processing the images into an array
    try:

        filepath = test_data_dir + '/'+ img
        IMG_SIZE = 35
        img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
        new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
        reshaped_array = new_array.reshape(IMG_SIZE, IMG_SIZE, 1)
        data.append(reshaped_array)
        
        counter += 1
        print("Count = {}".format(counter))

    except:
        print("Error in" +img)

x_test_pred=np.array(data)

#Making predictions

predicted = np.argmax(model.predict(x_test_pred),axis= -1)
# Out:
# Streaming output truncated to the last 5000 lines.
# Count = 7631
# Count = 7632
# Count = 7633
# Count = 7634
# Count = 7635
# Count = 7636
# Count = 7637
# Count = 7638
# Count = 7639
# Count = 7640
# Count = 7641
# Count = 7642
# Count = 7643
# Count = 7644
# Count = 7645
# Count = 7646
# Count = 7647
# Count = 7648
# Count = 7649
# Count = 7650
# Count = 7651
# Count = 7652
# Count = 7653
# Count = 7654
# Count = 7655
# Count = 7656
# Count = 7657
# Count = 7658
# Count = 7659
# Count = 7660
# Count = 7661
# Count = 7662
# Count = 7663
# Count = 7664
# Count = 7665
# Count = 7666
# Count = 7667
# Count = 7668
# Count = 7669
# Count = 7670
# Count = 7671
# Count = 7672
# Count = 7673
# Count = 7674
# Count = 7675
# Count = 7676
# Count = 7677
# Count = 7678
# Count = 7679
# Count = 7680
# Count = 7681
# Count = 7682
# Count = 7683
# Count = 7684
# Count = 7685
# Count = 7686
# Count = 7687
# Count = 7688
# Count = 7689
# Count = 7690
# Count = 7691
# Count = 7692
# Count = 7693
# Count = 7694
# Count = 7695
# Count = 7696
# Count = 7697
# Count = 7698
# Count = 7699
# Count = 7700
# Count = 7701
# Count = 7702
# Count = 7703
# Count = 7704
# Count = 7705
# Count = 7706
# Count = 7707
# Count = 7708
# Count = 7709
# Count = 7710
# Count = 7711
# Count = 7712
# Count = 7713
# Count = 7714
# Count = 7715
# Count = 7716
# Count = 7717
# Count = 7718
# Count = 7719
# Count = 7720
# Count = 7721
# Count = 7722
# Count = 7723
# Count = 7724
# Count = 7725
# Count = 7726
# Count = 7727
# Count = 7728
# Count = 7729
# Count = 7730
# Count = 7731
# Count = 7732
# Count = 7733
# Count = 7734
# Count = 7735
# Count = 7736
# Count = 7737
# Count = 7738
# Count = 7739
# Count = 7740
# Count = 7741
# Count = 7742
# Count = 7743
# Count = 7744
# Count = 7745
# Count = 7746
# Count = 7747
# Count = 7748
# Count = 7749
# Count = 7750
# Count = 7751
# Count = 7752
# Count = 7753
# Count = 7754
# Count = 7755
# Count = 7756
# Count = 7757
# Count = 7758
# Count = 7759
# Count = 7760
# Count = 7761
# Count = 7762
# Count = 7763
# Count = 7764
# Count = 7765
# Count = 7766
# Count = 7767
# Count = 7768
# Count = 7769
# Count = 8534
# Count = 8535
# Count = 8536
# Count = 8537
# Count = 8538
# Count = 8539
# Count = 8540
# Count = 8541
# Count = 8542
# Count = 8543
# Count = 8544
# Count = 8545
# Count = 8546
# Count = 8547
# Count = 8548
# Count = 8549
# Count = 8550
# Count = 8551
# Count = 8552
# Count = 8553
# Count = 8554
# Count = 8555
# Count = 8556
# Count = 8557
# Count = 8558
# Count = 8559
# Count = 8560
# Count = 8561
# Count = 8562
# Count = 8563
# Count = 8564
# Count = 8565
# Count = 8566
# Count = 8567
# Count = 8568
# Count = 8569
# Count = 8570
# Count = 8571
# Count = 8572
# Count = 8573
# Count = 8574
# Count = 8575
# Count = 8576
# Count = 8577
# Count = 8578
# Count = 8579
# Count = 8580
# Count = 8581
# Count = 8582
# Count = 8583
# Count = 8584
# Count = 8585
# Count = 8586
# Count = 8587
# Count = 8588
# Count = 8589
# Count = 8590
# Count = 8591
# Count = 8592
# Count = 8593
# Count = 8594
# Count = 8595
# Count = 8596
# Count = 8597
# Count = 8598
# Count = 8599
# Count = 8600
# Count = 8601
# Count = 8602
# Count = 8603
# Count = 8604
# Count = 8605
# Count = 8606
# Count = 8607
# Count = 8608
# Count = 8609
# Count = 8610
# Count = 8611
# Count = 8612
# Count = 8613
# Count = 8614
# Count = 8615
# Count = 8616
# Count = 8617
# Count = 8618
# Count = 8619
# Count = 8620
# Count = 8621
# Count = 8622
# Count = 8623
# Count = 8624
# Count = 8625
# Count = 8626
# Count = 8627
# Count = 8628
# Count = 8629
# Count = 8630
# Count = 8631
# Count = 8632
# Count = 8633
# Count = 8634
# Count = 8635
# Count = 8636
# Count = 8637
# Count = 8638
# Count = 8639
# Count = 8640
# Count = 8641
# Count = 8642
# Count = 8643
# Count = 8644
# Count = 8645
# Count = 8646
# Count = 8647
# Count = 8648
# Count = 8649
# Count = 8650
# Count = 8651
# Count = 8652
# Count = 8653
# Count = 8654
# Count = 8655
# Count = 8656
# Count = 8657
# Count = 8658
# Count = 8659
# Count = 8660
# Count = 8661
# Count = 8662
# Count = 8663
# Count = 8664
# Count = 8665
# Count = 8666
# Count = 8667
# Count = 8668
# Count = 8669
# Count = 8670
# Count = 8671
# Count = 8672
# Count = 8673
# Count = 8674
# Count = 8675
# Count = 8676
# Count = 8677
# Count = 8678
# Count = 8679
# Count = 8680
# Count = 8681
# Count = 8682
# Count = 8683
# Count = 8684
# Count = 8685
# Count = 8686
# Count = 8687
# Count = 8688
# Count = 8689
# Count = 8690
# Count = 8691
# Count = 8692
# Count = 8693
# Count = 8694
# Count = 8695
# Count = 8696
# Count = 8697
# Count = 8698
# Count = 8699
# Count = 8700
# Count = 8701
# Count = 8702
# Count = 8703
# Count = 8704
# Count = 8705
# Count = 8706
# Count = 8707
# Count = 8708
# Count = 8709
# Count = 8710
# Count = 8711
# Count = 8712
# Count = 8713
# Count = 8714
# Count = 8715
# Count = 8716
# Count = 8717
# Count = 8718
# Count = 8719
# Count = 8720
# Count = 8721
# Count = 8722
# Count = 8723
# Count = 8724
# Count = 8725
# Count = 8726
# Count = 8727
# Count = 8728
# Count = 8729
# Count = 8730
# Count = 8731
# Count = 8732
# Count = 8733
# Count = 8734
# Count = 8735
# Count = 8736
# Count = 8737
# Count = 8738
# Count = 8739
# Count = 8740
# Count = 8741
# Count = 8742
# Count = 8743
# Count = 8744
# Count = 8745
# Count = 8746
# Count = 8747
# Count = 8748
# Count = 8749
# Count = 8750
# Count = 8751
# Count = 8752
# Count = 8753
# Count = 8754
# Count = 8755
# Count = 8756
# Count = 8757
# Count = 8758
# Count = 8759
# Count = 8760
# Count = 8761
# Count = 8762
# Count = 8763
# Count = 8764
# Count = 8765
# Count = 8766
# Count = 8767
# Count = 8768
# Count = 8769
# Count = 8770
# Count = 8771
# Count = 8772
# Count = 8773
# Count = 8774
# Count = 8775
# Count = 8776
# Count = 8777
# Count = 8778
# Count = 8779
# Count = 8780
# Count = 8781
# Count = 8782
# Count = 8783
# Count = 8784
# Count = 8785
# Count = 8786
# Count = 8787
# Count = 8788
# Count = 8789
# Count = 8790
# Count = 8791
# Count = 8792
# Count = 8793
# Count = 8794
# Count = 8795
# Count = 8796
# Count = 8797
# Count = 8798
# Count = 8799
# Count = 8800
# Count = 8801
# Count = 8802
# Count = 8803
# Count = 8804
# Count = 8805
# Count = 8806
# Count = 8807
# Count = 8808
# Count = 8809
# Count = 8810
# Count = 8811
# Count = 8812
# Count = 8813
# Count = 8814
# Count = 8815
# Count = 8816
# Count = 8817
# Count = 8818
# Count = 8819
# Count = 8820
# Count = 8821
# Count = 8822
# Count = 8823
# Count = 8824
# Count = 8825
# Count = 8826
# Count = 8827
# Count = 8828
# Count = 8829
# Count = 8830
# Count = 8831
# Count = 8832
# Count = 8833
# Count = 8834
# Count = 8835
# Count = 8836
# Count = 8837
# Count = 8838
# Count = 8839
# Count = 8840
# Count = 8841
# Count = 8842
# Count = 8843
# Count = 8844
# Count = 8845
# Count = 8846
# Count = 8847
# Count = 8848
# Count = 8849
# Count = 8850
# Count = 8851
# Count = 8852
# Count = 8853
# Count = 8854
# Count = 8855
# Count = 8856
# Count = 8857
# Count = 8858
# Count = 8859
# Count = 8860
# Count = 8861
# Count = 8862
# Count = 8863
# Count = 8864
# Count = 8865
# Count = 8866
# Count = 8867
# Count = 8868
# Count = 8869
# Count = 8870
# Count = 8871
# Count = 8872
# Count = 8873
# Count = 8874
# Count = 8875
# Count = 8876
# Count = 8877
# Count = 8878
# Count = 8879
# Count = 8880
# Count = 8881
# Count = 8882
# Count = 8883
# Count = 8884
# Count = 8885
# Count = 8886
# Count = 8887
# Count = 8888
# Count = 8889
# Count = 8890
# Count = 8891
# Count = 8892
# Count = 8893
# Count = 8894
# Count = 8895
# Count = 8896
# Count = 8897
# Count = 8898
# Count = 8899
# Count = 8900
# Count = 8901
# Count = 8902
# Count = 8903
# Count = 8904
# Count = 8905
# Count = 8906
# Count = 8907
# Count = 8908
# Count = 8909
# Count = 8910
# Count = 8911
# Count = 8912
# Count = 8913
# Count = 8914
# Count = 8915
# Count = 10252
# Count = 10253
# Count = 10254
# Count = 10255
# Count = 10256
# Count = 10257
# Count = 10258
# Count = 10259
# Count = 10260
# Count = 10261
# Count = 10262
# Count = 10263
# Count = 10264
# Count = 10265
# Count = 10266
# Count = 10267
# Count = 10268
# Count = 10269
# Count = 10270
# Count = 10271
# Count = 10272
# Count = 10273
# Count = 10274
# Count = 10275
# Count = 10276
# Count = 10277
# Count = 10278
# Count = 10279
# Count = 10280
# Count = 10281
# Count = 10282
# Count = 10283
# Count = 10284
# Count = 10285
# Count = 10286
# Count = 10287
# Count = 10288
# Count = 10289
# Count = 10290
# Count = 10291
# Count = 10292
# Count = 10293
# Count = 10294
# Count = 10295
# Count = 10296
# Count = 10297
# Count = 10298
# Count = 10299
# Count = 10300
# Count = 10301
# Count = 10302
# Count = 10303
# Count = 10304
# Count = 10305
# Count = 10306
# Count = 10307
# Count = 10308
# Count = 10309
# Count = 10310
# Count = 10311
# Count = 10312
# Count = 10313
# Count = 10314
# Count = 10315
# Count = 10316
# Count = 10317
# Count = 10318
# Count = 10319
# Count = 10320
# Count = 10321
# Count = 10322
# Count = 10323
# Count = 10324
# Count = 10325
# Count = 10326
# Count = 10327
# Count = 10328
# Count = 10329
# Count = 10330
# Count = 10331
# Count = 10332
# Count = 10333
# Count = 10334
# Count = 10335
# Count = 10336
# Count = 10337
# Count = 10338
# Count = 10339
# Count = 10340
# Count = 10341
# Count = 10342
# Count = 10343
# Count = 10344
# Count = 10345
# Count = 10346
# Count = 10347
# Count = 10348
# Count = 10349
# Count = 10350
# Count = 10351
# Count = 10352
# Count = 10353
# Count = 10354
# Count = 10355
# Count = 10356
# Count = 10357
# Count = 10358
# Count = 10359
# Count = 10360
# Count = 10361
# Count = 10362
# Count = 10363
# Count = 10364
# Count = 10365
# Count = 10366
# Count = 10367
# Count = 10368
# Count = 10369
# Count = 10370
# Count = 10371
# Count = 10372
# Count = 10373
# Count = 10374
# Count = 10375
# Count = 10376
# Count = 10377
# Count = 10378
# Count = 10379
# Count = 10380
# Count = 10381
# Count = 10382
# Count = 10383
# Count = 10384
# Count = 10385
# Count = 10386
# Count = 10387
# Count = 10388
# Count = 10389
# Count = 10390
# Count = 10391
# Count = 10392
# Count = 10393
# Count = 10394
# Count = 10395
# Count = 10396
# Count = 10397
# Count = 10398
# Count = 10399
# Count = 10400
# Count = 10401
# Count = 10402
# Count = 10403
# Count = 10404
# Count = 10405
# Count = 10406
# Count = 10407
# Count = 10408
# Count = 10409
# Count = 10410
# Count = 10411
# Count = 10412
# Count = 10413
# Count = 10414
# Count = 10415
# Count = 10416
# Count = 10417
# Count = 10418
# Count = 10419
# Count = 10420
# Count = 10421
# Count = 10422
# Count = 10423
# Count = 10424
# Count = 10425
# Count = 10426
# Count = 10427
# Count = 10428
# Count = 10429
# Count = 10430
# Count = 10431
# Count = 10432
# Count = 10433
# Count = 10434
# Count = 10435
# Count = 10436
# Count = 10437
# Count = 10438
# Count = 10439
# Count = 10440
# Count = 10441
# Count = 10442
# Count = 10825
# Count = 10826
# Count = 10827
# Count = 10828
# Count = 10829
# Count = 10830
# Count = 10831
# Count = 10832
# Count = 10833
# Count = 10834
# Count = 10835
# Count = 10836
# Count = 10837
# Count = 10838
# Count = 10839
# Count = 10840
# Count = 10841
# Count = 10842
# Count = 10843
# Count = 10844
# Count = 10845
# Count = 10846
# Count = 10847
# Count = 10848
# Count = 10849
# Count = 10850
# Count = 10851
# Count = 10852
# Count = 10853
# Count = 10854
# Count = 10855
# Count = 10856
# Count = 10857
# Count = 10858
# Count = 10859
# Count = 10860
# Count = 10861
# Count = 10862
# Count = 10863
# Count = 10864
# Count = 10865
# Count = 10866
# Count = 10867
# Count = 10868
# Count = 10869
# Count = 10870
# Count = 10871
# Count = 10872
# Count = 10873
# Count = 10874
# Count = 10875
# Count = 10876
# Count = 10877
# Count = 10878
# Count = 10879
# Count = 10880
# Count = 10881
# Count = 10882
# Count = 10883
# Count = 10884
# Count = 10885
# Count = 10886
# Count = 10887
# Count = 10888
# Count = 10889
# Count = 10890
# Count = 10891
# Count = 10892
# Count = 10893
# Count = 10894
# Count = 10895
# Count = 10896
# Count = 10897
# Count = 10898
# Count = 10899
# Count = 10900
# Count = 10901
# Count = 10902
# Count = 10903
# Count = 10904
# Count = 10905
# Count = 10906
# Count = 10907
# Count = 10908
# Count = 10909
# Count = 10910
# Count = 10911
# Count = 10912
# Count = 10913
# Count = 10914
# Count = 10915
# Count = 10916
# Count = 10917
# Count = 10918
# Count = 10919
# Count = 10920
# Count = 10921
# Count = 10922
# Count = 10923
# Count = 10924
# Count = 10925
# Count = 10926
# Count = 10927
# Count = 10928
# Count = 10929
# Count = 10930
# Count = 10931
# Count = 10932
# Count = 10933
# Count = 10934
# Count = 10935
# Count = 10936
# Count = 10937
# Count = 10938
# Count = 10939
# Count = 10940
# Count = 10941
# Count = 10942
# Count = 10943
# Count = 10944
# Count = 10945
# Count = 10946
# Count = 10947
# Count = 10948
# Count = 10949
# Count = 10950
# Count = 10951
# Count = 10952
# Count = 10953
# Count = 10954
# Count = 10955
# Count = 10956
# Count = 10957
# Count = 10958
# Count = 10959
# Count = 10960
# Count = 10961
# Count = 10962
# Count = 10963
# Count = 10964
# Count = 10965
# Count = 10966
# Count = 10967
# Count = 10968
# Count = 10969
# Count = 10970
# Count = 10971
# Count = 10972
# Count = 10973
# Count = 10974
# Count = 10975
# Count = 10976
# Count = 10977
# Count = 10978
# Count = 10979
# Count = 10980
# Count = 10981
# Count = 10982
# Count = 10983
# Count = 10984
# Count = 10985
# Count = 10986
# Count = 10987
# Count = 10988
# Count = 10989
# Count = 10990
# Count = 10991
# Count = 10992
# Count = 10993
# Count = 10994
# Count = 10995
# Count = 10996
# Count = 10997
# Count = 10998
# Count = 10999
# Count = 11000
# Count = 11001
# Count = 11002
# Count = 11003
# Count = 11004
# Count = 11005
# Count = 11006
# Count = 11007
# Count = 11008
# Count = 11009
# Count = 11010
# Count = 11011
# Count = 11012
# Count = 11013
# Count = 11014
# Count = 11015
# Count = 11207
# Count = 11208
# Count = 11209
# Count = 11210
# Count = 11211
# Count = 11212
# Count = 11213
# Count = 11214
# Count = 11215
# Count = 11216
# Count = 11217
# Count = 11218
# Count = 11219
# Count = 11220
# Count = 11221
# Count = 11222
# Count = 11223
# Count = 11224
# ...
# Count = 11489
# Count = 11490
# Count = 11491
# Count = 11492
# Count = 11493
# Count = 11494
# Count = 11495
# Count = 11496
# Count = 11497
# Count = 11498
# Count = 11499
# Count = 11500
# Count = 11501
# Count = 11502
# Count = 11503
# Count = 11504
# Count = 11505
# Count = 11506
# Count = 11507
# Count = 11508
# Count = 11509
# Count = 11510
# Count = 11511
# Count = 11512
# Count = 11513
# Count = 11514
# Count = 11515
# Count = 11516
# Count = 11517
# Count = 11518
# Count = 11519
# Count = 11520
# Count = 11521
# Count = 11522
# Count = 11523
# Count = 11524
# Count = 11525
# Count = 11526
# Count = 11527
# Count = 11528
# Count = 11529
# Count = 11530
# Count = 11531
# Count = 11532
# Count = 11533
# Count = 11534
# Count = 11535
# Count = 11536
# Count = 11537
# Count = 11538
# Count = 11539
# Count = 11540
# Count = 11541
# Count = 11542
# Count = 11543
# Count = 11544
# Count = 11545
# Count = 11546
# Count = 11547
# Count = 11548
# Count = 11549
# Count = 11550
# Count = 11551
# Count = 11552
# Count = 11553
# Count = 11554
# Count = 11555
# Count = 11556
# Count = 11557
# Count = 11558
# Count = 11559
# Count = 11560
# Count = 11561
# Count = 11562
# Count = 11563
# Count = 11564
# Count = 11565
# Count = 11566
# Count = 11567
# Count = 11568
# Count = 11569
# Count = 11570
# Count = 11571
# Count = 11572
# Count = 11573
# Count = 11574
# Count = 11575
# Count = 11576
# Count = 11577
# Count = 11578
# Count = 11579
# Count = 11580
# Count = 11581
# Count = 11582
# Count = 11583
# Count = 11584
# Count = 11585
# Count = 11586
# Count = 11587
# Count = 11588
# Count = 11589
# Count = 11590
# Count = 11591
# Count = 11592
# Count = 11593
# Count = 11594
# Count = 11595
# Count = 11596
# Count = 11597
# Count = 11598
# Count = 11599
# Count = 11600
# Count = 11601
# Count = 11602
# Count = 11603
# Count = 11604
# Count = 11605
# Count = 11606
# Count = 11607
# Count = 11608
# Count = 11609
# Count = 11610
# Count = 11611
# Count = 11612
# Count = 11613
# Count = 11614
# Count = 11615
# Count = 11616
# Count = 11617
# Count = 11618
# Count = 11619
# Count = 11620
# Count = 11621
# Count = 11622
# Count = 11623
# Count = 11624
# Count = 11625
# Count = 11626
# Count = 11627
# Count = 11628
# Count = 11629
# Count = 11630
# Count = 11631
# Count = 11632
# Count = 11633
# Count = 11634
# Count = 11635
# Count = 11636
# Count = 11637
# Count = 11638
# Count = 11639
# Count = 11640
# Count = 11641
# Count = 11642
# Count = 11643
# Count = 11644
# Count = 11645
# Count = 11646
# Count = 11647
# Count = 11648
# Count = 11649
# Count = 11650
# Count = 11651
# Count = 11652
# Count = 11653
# Count = 11654
# Count = 11655
# Count = 11656
# Count = 11657
# Count = 11658
# Count = 11659
# Count = 11660
# Count = 11661
# Count = 11662
# Count = 11663
# Count = 11664
# Count = 11665
# Count = 11666
# Count = 11667
# Count = 11668
# Count = 11669
# Count = 11670
# Count = 11671
# Count = 11672
# Count = 11673
# Count = 11674
# Count = 11675
# Count = 11676
# Count = 11677
# Count = 11678
# Count = 11679
# Count = 11680
# Count = 11681
# Count = 11682
# Count = 11683
# Count = 11684
# Count = 11685
# Count = 11686
# Count = 11687
# Count = 11688
# Count = 11689
# Count = 11690
# Count = 11691
# Count = 11692
# Count = 11693
# Count = 11694
# Count = 11695
# Count = 11696
# Count = 11697
# Count = 11698
# Count = 11699
# Count = 11700
# Count = 11701
# Count = 11702
# Count = 11703
# Count = 11704
# Count = 11705
# Count = 11706
# Count = 11707
# Count = 11708
# Count = 11709
# Count = 11710
# Count = 11711
# Count = 11712
# Count = 11713
# Count = 11714
# Count = 11715
# Count = 11716
# Count = 11717
# Count = 11718
# Count = 11719
# Count = 11720
# Count = 11721
# Count = 11722
# Count = 11723
# Count = 11724
# Count = 11725
# Count = 11726
# Count = 11727
# Count = 11728
# Count = 11729
# Count = 11730
# Count = 11731
# Count = 11732
# Count = 11733
# Count = 11734
# Count = 11735
# Count = 11736
# Count = 11737
# Count = 11738
# Count = 11739
# Count = 11740
# Count = 11741
# Count = 11742
# Count = 11743
# Count = 11744
# Count = 11745
# Count = 11746
# Count = 11747
# Count = 11748
# Count = 11749
# Count = 11750
# Count = 11751
# Count = 11752
# Count = 11753
# Count = 11754
# Count = 11755
# Count = 11756
# Count = 11757
# Count = 11758
# Count = 11759
# Count = 11760
# Count = 11761
# Count = 11762
# Count = 11763
# Count = 11764
# Count = 11765
# Count = 11766
# Count = 11767
# Count = 11768
# Count = 11769
# Count = 11770
# Count = 11771
# Count = 11772
# Count = 11773
# Count = 11774
# Count = 11775
# Count = 11776
# Count = 11777
# Count = 11778
# Count = 11779
# Count = 11780
# Count = 11781
# Count = 11782
# Count = 11783
# Count = 11784
# Count = 11785
# Count = 11786
# Count = 11787
# Count = 11788
# Count = 11789
# Count = 11790
# Count = 11791
# Count = 11792
# Count = 11793
# Count = 11794
# Count = 11795
# Count = 11796
# Count = 11797
# Count = 11798
# Count = 11799
# Count = 11800
# Count = 11801
# Count = 11802
# Count = 11803
# Count = 11804
# Count = 11805
# Count = 11806
# Count = 11807
# Count = 11808
# Count = 11809
# Count = 11810
# Count = 11811
# Count = 11812
# Count = 11813
# Count = 11814
# Count = 11815
# Count = 11816
# Count = 11817
# Count = 11818
# Count = 11819
# Count = 11820
# Count = 11821
# Count = 11822
# Count = 11823
# Count = 11824
# Count = 11825
# Count = 11826
# Count = 11827
# Count = 11828
# Count = 11829
# Count = 11830
# Count = 11831
# Count = 11832
# Count = 11833
# Count = 11834
# Count = 11835
# Count = 11836
# Count = 11837
# Count = 11838
# Count = 11839
# Count = 11840
# Count = 11841
# Count = 11842
# Count = 11843
# Count = 11844
# Count = 11845
# Count = 11846
# Count = 11847
# Count = 11848
# Count = 11849
# Count = 11850
# Count = 11851
# Count = 11852
# Count = 11853
# Count = 11854
# Count = 11855
# Count = 11856
# Count = 11857
# Count = 11858
# Count = 11859
# Count = 11860
# Count = 11861
# Count = 11862
# Count = 11863
# Count = 11864
# Count = 11865
# Count = 11866
# Count = 11867
# Count = 11868
# Count = 11869
# Count = 11870
# Count = 11871
# Count = 11872
# Count = 11873
# Count = 11874
# Count = 11875
# Count = 11876
# Count = 11877
# Count = 11878
# Count = 11879
# Count = 11880
# Count = 11881
# Count = 11882
# Count = 11883
# Count = 11884
# Count = 11885
# Count = 11886
# Count = 11887
# Count = 11888
# Count = 11889
# Count = 11890
# Count = 11891
# Count = 11892
# Count = 11893
# Count = 11894
# Count = 11895
# Count = 11896
# Count = 11897
# Count = 11898
# Count = 11899
# Count = 11900
# Count = 11901
# Count = 11902
# Count = 11903
# Count = 11904
# Count = 11905
# Count = 11906
# Count = 11907
# Count = 11908
# Count = 11909
# Count = 11910
# Count = 11911
# Count = 11912
# Count = 11913
# Count = 11914
# Count = 11915
# Count = 11916
# Count = 11917
# Count = 11918
# Count = 11919
# Count = 11920
# Count = 11921
# Count = 11922
# Count = 11923
# Count = 11924
# Count = 11925
# Count = 11926
# Count = 11927
# Count = 11928
# Count = 11929
# Count = 11930
# Count = 11931
# Count = 11932
# Count = 11933
# Count = 11934
# Count = 11935
# Count = 11936
# Count = 11937
# Count = 11938
# Count = 11939
# Count = 11940
# Count = 11941
# Count = 11942
# Count = 11943
# Count = 11944
# Count = 11945
# Count = 11946
# Count = 11947
# Count = 11948
# Count = 11949
# Count = 11950
# Count = 11951
# Count = 11952
# Count = 11953
# Count = 11954
# Count = 11955
# Count = 11956
# Count = 11957
# Count = 11958
# Count = 11959
# Count = 11960
# Count = 11961
# Count = 11962
# Count = 11963
# Count = 11964
# Count = 11965
# Count = 11966
# Count = 11967
# Count = 11968
# Count = 11969
# Count = 11970
# Count = 11971
# Count = 11972
# Count = 11973
# Count = 11974
# Count = 11975
# Count = 11976
# Count = 11977
# Count = 11978
# Count = 11979
# Count = 11980
# Count = 11981
# Count = 11982
# Count = 11983
# Count = 11984
# Count = 11985
# Count = 11986
# Count = 11987
# Count = 11988
# Count = 11989
# Count = 11990
# Count = 11991
# Count = 11992
# Count = 11993
# Count = 11994
# Count = 11995
# Count = 11996
# Count = 11997
# Count = 11998
# Count = 11999
# Count = 12000
# Count = 12001
# Count = 12002
# Count = 12003
# Count = 12004
# Count = 12005
# Count = 12006
# Count = 12007
# Count = 12008
# Count = 12009
# Count = 12010
# Count = 12011
# Count = 12012
# Count = 12013
# Count = 12014
# Count = 12015
# Count = 12016
# Count = 12017
# Count = 12018
# Count = 12019
# Count = 12020
# Count = 12021
# Count = 12022
# Count = 12023
# Count = 12024
# Count = 12025
# Count = 12026
# Count = 12027
# Count = 12028
# Count = 12029
# Count = 12030
# Count = 12031
# Count = 12032
# Count = 12033
# Count = 12034
# Count = 12035
# Count = 12036
# Count = 12037
# Count = 12038
# Count = 12039
# Count = 12040
# Count = 12041
# Count = 12042
# Count = 12043
# Count = 12044
# Count = 12045
# Count = 12046
# Count = 12047
# Count = 12048
# Count = 12049
# Count = 12050
# Count = 12051
# Count = 12052
# Count = 12053
# Count = 12054
# Count = 12055
# Count = 12056
# Count = 12057
# Count = 12058
# Count = 12059
# Count = 12060
# Count = 12061
# Count = 12062
# Count = 12063
# Count = 12064
# Count = 12065
# Count = 12066
# Count = 12067
# Count = 12068
# Count = 12069
# Count = 12070
# Count = 12071
# Count = 12072
# Count = 12073
# Count = 12074
# Count = 12075
# Count = 12076
# Count = 12077
# Count = 12078
# Count = 12079
# Count = 12080
# Count = 12081
# Count = 12082
# Count = 12083
# Count = 12084
# Count = 12085
# Count = 12086
# Count = 12087
# Count = 12088
# Count = 12089
# Count = 12090
# Count = 12091
# Count = 12092
# Count = 12093
# Count = 12094
# Count = 12095
# Count = 12096
# Count = 12097
# Count = 12098
# Count = 12099
# Count = 12100
# Count = 12101
# Count = 12102
# Count = 12103
# Count = 12104
# Count = 12105
# Count = 12106
# Count = 12107
# Count = 12108
# Count = 12109
# Count = 12110
# Count = 12111
# Count = 12112
# Count = 12113
# Count = 12114
# Count = 12115
# Count = 12116
# Count = 12117
# Count = 12118
# Count = 12119
# Count = 12120
# Count = 12121
# Count = 12122
# Count = 12123
# Count = 12124
# Count = 12125
# Count = 12126
# Count = 12127
# Count = 12128
# Count = 12129
# Count = 12130
# Count = 12131
# Count = 12132
# Count = 12133
# Count = 12134
# Count = 12135
# Count = 12136
# Count = 12137
# Count = 12138
# Count = 12139
# Count = 12140
# Count = 12141
# Count = 12142
# Count = 12143
# Count = 12144
# Count = 12145
# Count = 12146
# Count = 12147
# Count = 12148
# Count = 12149
# Count = 12150
# Count = 12151
# Count = 12152
# Count = 12153
# Count = 12154
# Count = 12155
# Count = 12156
# Count = 12157
# Count = 12158
# Count = 12159
# Count = 12160
# Count = 12161
# Count = 12162
# Count = 12163
# Count = 12164
# Count = 12165
# Count = 12166
# Count = 12167
# Count = 12168
# Count = 12169
# Count = 12170
# Count = 12171
# Count = 12172
# Count = 12173
# Count = 12174
# Count = 12175
# Count = 12176
# Count = 12177
# Count = 12178
# Count = 12179
# Count = 12180
# Count = 12181
# Count = 12182
# Count = 12183
# Count = 12184
# Count = 12185
# Count = 12186
# Count = 12187
# Count = 12188
# Count = 12189
# Count = 12190
# Count = 12191
# Count = 12192
# Count = 12193
# Count = 12194
# Count = 12195
# Count = 12196
# Count = 12197
# Count = 12198
# Count = 12199
# Count = 12200
# Count = 12201
# Count = 12202
# Count = 12203
# Count = 12204
# Count = 12205
# Count = 12206
# Count = 12207
# Count = 12208
# Count = 12209
# Count = 12210
# Count = 12211
# Count = 12212
# Count = 12213
# Count = 12214
# Count = 12215
# Count = 12216
# Count = 12217
# Count = 12218
# Count = 12219
# Count = 12220
# Count = 12221
# Count = 12222
# Count = 12223
# Count = 12224
# Count = 12225
# Count = 12226
# Count = 12227
# Count = 12228
# Count = 12229
# Count = 12230
# Count = 12231
# Count = 12232
# Count = 12233
# Count = 12234
# Count = 12235
# Count = 12236
# Count = 12237
# Count = 12238
# Count = 12239
# Count = 12240
# Count = 12241
# Count = 12242
# Count = 12243
# Count = 12244
# Count = 12245
# Count = 12246
# Count = 12247
# Count = 12248
# Count = 12249
# Count = 12250
# Count = 12251
# Count = 12252
# Count = 12253
# Count = 12254
# Count = 12255
# Count = 12256
# Count = 12257
# Count = 12258
# Count = 12259
# Count = 12260
# Count = 12261
# Count = 12262
# Count = 12263
# Count = 12264
# Count = 12265
# Count = 12266
# Count = 12267
# Count = 12268
# Count = 12269
# Count = 12270
# Count = 12271
# Count = 12272
# Count = 12273
# Count = 12274
# Count = 12275
# Count = 12276
# Count = 12277
# Count = 12278
# Count = 12279
# Count = 12280
# Count = 12281
# Count = 12282
# Count = 12283
# Count = 12284
# Count = 12285
# Count = 12286
# Count = 12287
# Count = 12288
# Count = 12289
# Count = 12290
# Count = 12291
# Count = 12292
# Count = 12293
# Count = 12294
# Count = 12295
# Count = 12296
# Count = 12297
# Count = 12298
# Count = 12299
# Count = 12300
# Count = 12301
# Count = 12302
# Count = 12303
# Count = 12304
# Count = 12305
# Count = 12306
# Count = 12307
# Count = 12308
# Count = 12309
# Count = 12310
# Count = 12311
# Count = 12312
# Count = 12313
# Count = 12314
# Count = 12315
# Count = 12316
# Count = 12317
# Count = 12318
# Count = 12319
# Count = 12320
# Count = 12321
# Count = 12322
# Count = 12323
# Count = 12324
# Count = 12325
# Count = 12326
# Count = 12327
# Count = 12328
# Count = 12329
# Count = 12330
# Count = 12331
# Count = 12332
# Count = 12333
# Count = 12334
# Count = 12335
# Count = 12336
# Count = 12337
# Count = 12338
# Count = 12339
# Count = 12340
# Count = 12341
# Count = 12342
# Count = 12343
# Count = 12344
# Count = 12345
# Count = 12346
# Count = 12347
# Count = 12348
# Count = 12349
# Count = 12350
# Count = 12351
# Count = 12352
# Count = 12353
# Count = 12354
# Count = 12355
# Count = 12356
# Count = 12357
# Count = 12358
# Count = 12359
# Count = 12360
# Count = 12361
# Count = 12362
# Count = 12363
# Count = 12364
# Count = 12365
# Count = 12366
# Count = 12367
# Count = 12368
# Count = 12369
# Count = 12370
# Count = 12371
# Count = 12372
# Count = 12373
# Count = 12374
# Count = 12375
# Count = 12376
# Count = 12377
# Count = 12378
# Count = 12379
# Count = 12380
# Count = 12381
# Count = 12382
# Count = 12383
# Count = 12384
# Count = 12385
# Count = 12386
# Count = 12387
# Count = 12388
# Count = 12389
# Count = 12390
# Count = 12391
# Count = 12392
# Count = 12393
# Count = 12394
# Count = 12395
# Count = 12396
# Count = 12397
# Count = 12398
# Count = 12399
# Count = 12400
# Count = 12401
# Count = 12402
# Count = 12403
# Count = 12404
# Count = 12405
# Count = 12406
# Count = 12407
# Count = 12408
# Count = 12409
# Count = 12410
# Count = 12411
# Count = 12412
# Count = 12413
# Count = 12414
# Count = 12415
# Count = 12416
# Count = 12417
# Count = 12418
# Count = 12419
# Count = 12420
# Count = 12421
# Count = 12422
# Count = 12423
# Count = 12424
# Count = 12425
# Count = 12426
# Count = 12427
# Count = 12428
# Count = 12429
# Count = 12430
# Count = 12431
# Count = 12432
# Count = 12433
# Count = 12434
# Count = 12435
# Count = 12436
# Count = 12437
# Count = 12438
# Count = 12439
# Count = 12440
# Count = 12441
# Count = 12442
# Count = 12443
# Count = 12444
# Count = 12445
# Count = 12446
# Count = 12447
# Count = 12448
# Count = 12449
# Count = 12450
# Count = 12451
# Count = 12452
# Count = 12453
# Count = 12454
# Count = 12455
# Count = 12456
# Count = 12457
# Count = 12458
# Count = 12459
# Count = 12460
# Count = 12461
# Count = 12462
# Count = 12463
# Count = 12464
# Count = 12465
# Count = 12466
# Count = 12467
# Count = 12468
# Count = 12469
# Count = 12470
# Count = 12471
# Count = 12472
# Count = 12473
# Count = 12474
# Count = 12475
# Count = 12476
# Count = 12477
# Count = 12478
# Count = 12479
# Count = 12480
# Count = 12481
# Count = 12482
# Count = 12483
# Count = 12484
# Count = 12485
# Count = 12486
# Count = 12487
# Count = 12488
# Count = 12489
# Count = 12490
# Count = 12491
# Count = 12492
# Count = 12493
# Count = 12494
# Count = 12495
# Count = 12496
# Count = 12497
# Count = 12498
# Count = 12499
# Count = 12500
# Count = 12501
# Count = 12502
# Count = 12503
# Count = 12504
# Count = 12505
# Count = 12506
# Count = 12507
# Count = 12508
# Count = 12509
# Count = 12510
# Count = 12511
# Count = 12512
# Count = 12513
# Count = 12514
# Count = 12515
# Count = 12516
# Count = 12517
# Count = 12518
# Count = 12519
# Count = 12520
# Count = 12521
# Count = 12522
# Count = 12523
# Count = 12524
# Count = 12525
# Count = 12526
# Count = 12527
# Count = 12528
# Count = 12529
# Count = 12530
# Count = 12531
# Count = 12532
# Count = 12533
# Count = 12534
# Count = 12535
# Count = 12536
# Count = 12537
# Count = 12538
# Count = 12539
# Count = 12540
# Count = 12541
# Count = 12542
# Count = 12543
# Count = 12544
# Count = 12545
# Count = 12546
# Count = 12547
# Count = 12548
# Count = 12549
# Count = 12550
# Count = 12551
# Count = 12552
# Count = 12553
# Count = 12554
# Count = 12555
# Count = 12556
# Count = 12557
# Count = 12558
# Count = 12559
# Count = 12560
# Count = 12561
# Count = 12562
# Count = 12563
# Count = 12564
# Count = 12565
# Count = 12566
# Count = 12567
# Count = 12568
# Count = 12569
# Count = 12570
# Count = 12571
# Count = 12572
# Count = 12573
# Count = 12574
# Count = 12575
# Count = 12576
# Count = 12577
# Count = 12578
# Count = 12579
# Count = 12580
# Count = 12581
# Count = 12582
# Count = 12583
# Count = 12584
# Count = 12585
# Count = 12586
# Count = 12587
# Count = 12588
# Count = 12589
# Count = 12590
# Count = 12591
# Count = 12592
# Count = 12593
# Count = 12594
# Count = 12595
# Count = 12596
# Count = 12597
# Count = 12598
# Count = 12599
# Count = 12600
# Count = 12601
# Count = 12602
# Count = 12603
# Count = 12604
# Count = 12605
# Count = 12606
# Count = 12607
# Count = 12608
# Count = 12609
# Count = 12610
# Count = 12611
# Count = 12612
# Count = 12613
# Count = 12614
# Count = 12615
# Count = 12616
# Count = 12617
# Count = 12618
# Count = 12619
# Count = 12620
# Count = 12621
# Count = 12622
# Count = 12623
# Count = 12624
# Count = 12625
# Count = 12626
# Count = 12627
# Count = 12628
# Count = 12629
# Count = 12630

# %% [markdown]
# #5. Model Evaluation

# %% [markdown]
# ## 5.1 Accuracy of the model

# %%
#Accuracy with the Test data

print('Test Data accuracy: ', accuracy_score(labels, predicted)*100)
# Out:
# Test Data accuracy:  93.03246239113221

# %% [markdown]
# ## 5.2 Report on the trained model

# %%
#Confusion Matrix

cf = confusion_matrix(labels, predicted)
df_cm = pd.DataFrame(cf, index = category_names,  columns = category_names)
plt.figure(figsize = (20,20))
sns.heatmap(df_cm, annot=True)

# %%
#Classification Report

print(classification_report(labels, predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.97      0.95        60
#            1       0.93      0.99      0.96       720
#            2       0.99      0.97      0.98       750
#            3       0.98      0.93      0.95       450
#            4       0.99      0.96      0.97       660
#            5       0.93      0.96      0.94       630
#            6       1.00      0.77      0.87       150
#            7       0.93      0.91      0.92       450
#            8       0.97      0.87      0.92       450
#            9       0.96      0.93      0.95       480
#           10       0.99      0.94      0.97       660
#           11       0.76      0.77      0.77       420
#           12       0.98      0.91      0.94       690
#           13       1.00      0.99      1.00       720
#           14       1.00      0.95      0.97       270
#           15       0.60      1.00      0.75       210
#           16       1.00      0.99      1.00       150
#           17       0.95      0.99      0.97       360
#           18       0.77      0.88      0.82       390
#           19       0.94      1.00      0.97        60
#           20       0.92      0.99      0.95        90
#           21       0.93      0.90      0.92        90
#           22       1.00      0.93      0.96       120
#           23       0.97      0.99      0.98       150
#           24       0.99      0.90      0.94        90
#           25       0.95      0.95      0.95       480
#           26       0.91      0.33      0.48       180
#           27       0.96      0.42      0.58        60
#           28       0.98      0.96      0.97       150
#           29       0.82      0.99      0.89        90
#           30       0.57      0.74      0.64       150
#           31       0.87      0.99      0.93       270
#           32       1.00      0.98      0.99        60
#           33       0.94      1.00      0.97       210
#           34       0.88      0.99      0.93       120
#           35       0.96      0.97      0.97       390
#           36       0.96      0.97      0.96       120
#           37       1.00      0.93      0.97        60
#           38       0.95      0.99      0.97       690
#           39       1.00      0.97      0.98        90
#           40       0.79      0.86      0.82        90
#           41       0.96      0.92      0.94        60
#           42       1.00      0.86      0.92        90
#
#     accuracy                           0.93     12630
#    macro avg       0.93      0.91      0.91     12630
# weighted avg       0.94      0.93      0.93     12630

# %% [markdown]
# ## 5.3 Visualizing the results

# %% [markdown]
# Comparing the actual ouput versus the predicted output on random images from test dataset

# %%
plt.figure(figsize = (30, 30))

start_index = 0
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.grid(False)
    plt.xticks([])
    plt.yticks([])
    prediction = predicted[start_index + i]
    actual = labels[start_index + i]

    predicted_label = category_names[prediction]
    actual_label = category_names[actual]

    col = 'g'
    if prediction != actual:
        col = 'r'
    plt.xlabel('Actual={} || Pred={}'.format(actual, prediction), color = col)
    plt.xlabel('Actual={} || Pred={}'.format(actual_label, predicted_label), color = col)
    plt.imshow(x_test_pred[start_index + i][:,:,0], cmap="gray")
plt.show()
